# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Input and Output

# %%
print("hello world")
# Out:
# hello world

# %%
print("AAAAAA","BBBBBB","CCCCCC")
# Out:
# AAAAAA BBBBBB CCCCCC

# %%
print("AAAAAA" "BBBBBB" "CCCCCC")
# Out:
# AAAAAABBBBBBCCCCCC

# %%
print(ABCD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_59/3774680780.py in <module>
# ----> 1 print(ABCD)
#
# NameError: name 'ABCD' is not defined

# %%
input()
# Out:
#  Hello :)
# 'Hello :)'

# %%
input("Please enter your name")
# Out:
# Please enter your name Aiden Thompson
# 'Aiden Thompson'

# %% [markdown]
# ## Variables

# %%
a = "This is a sentence"
b = "This is another sentence"

# %%
print("a:",a)
print("b:",b)
print("a,b:",a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_59/2157163333.py in <module>
# ----> 1 print("a:",a)
#       2 print("b:",b)
#       3 print("a,b:",a,b)
#
# NameError: name 'a' is not defined

# %%
ABCD=a""+b
# Out:
#   File "/tmp/ipykernel_59/1656974996.py", line 1
#     ABCD=a""+b
#            ^
# SyntaxError: invalid syntax

# %%
print("ABCD:",ABCD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_59/3673085877.py in <module>
# ----> 1 print("ABCD:",ABCD)
#
# NameError: name 'ABCD' is not defined

# %%
x=7.
y=8
print(x+y)
# Out:
# 15.0

# %%
l=(6,7,8,9)

# %%
print(l)
# Out:
# (6, 7, 8, 9)

# %%
print(l[0])
# Out:
# 6

# %%
print(l[3])
# Out:
# 9

# %%
print(len(l))
# Out:
# 4

# %%
print(l(10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_59/2538047326.py in <module>
# ----> 1 print(l(10))
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# # Arithmetic and Boolean Operators

# %%
print(l[0],"+",l[2],"=",l[0]+l[2])
# Out:
# 6 + 8 = 14

# %%
print(y,"^",l(0),"^",y=l[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_59/2969957395.py in <module>
# ----> 1 print(y,"^",l(0),"^",y=l[0])
#
# TypeError: 'tuple' object is not callable

# %%
print(l[3],"%",l[0],"=",l[3]%l[0])
# Out:
# 9 % 6 = 3

# %%
print("l[3]=",l[3],"l[0]=",l[0])
# Out:
# l[3]= 9 l[0]= 6

# %%
print(l[3]>l[0])
# Out:
# True

# %%
print(l[3]<l[0])
# Out:
# False

# %%
print(l[0]<l[0])
# Out:
# False

# %%
print(l[0]==l[0])
# Out:
# True

# %%
print(l[0]<=l[0])
# Out:
# True

# %%
print(l[0]>=l[0])
# Out:
# True
